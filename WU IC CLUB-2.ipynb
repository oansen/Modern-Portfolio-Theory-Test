# %%
#import packages
import pandas as pd
import numpy as np
import datetime as dt

import yfinance as yf

import statsmodels.api as sm
from statsmodels.stats import diagnostic as smd
from statsmodels.stats.sandwich_covariance import cov_hac

import matplotlib.pyplot as plt

pd.set_option("display.float_format", "{:,.2f}".format)

# %%
TICKERS = ["ADBE","ALB","GOOGL","BRK-B","QTUM","ONOF","RSP","MSFT","PLTR",
           "PYPL","RNMBY","XLE","TMUS","VOO","VXUS","VZ"] #select needed tickers

# %%
#download data from yahoo finance, px is our tickers, from start to end, with monthly prices, 
#no progress bar showing up (progress false), and auto_adjust which makes adj prices to close prics

px = yf.download(TICKERS, period="5y", interval="1mo", auto_adjust=True) 

#The if isinstance(px.columns, pd.MultiIndex): line checks whether the columns are multi-level
#If they are, it picks only the "Close" prices (or "Adj Close" if "Close" doesn’t exist).
#So you end up with a simple DataFrame where each column is one ticker 
if isinstance(px.columns, pd.MultiIndex):
    px = px["Close"] if "Close" in px.columns else px["Adj Close"]
else:
    px = px

#removes rows that are completely empty (in case some months have missing data for all tickers)
#.dropna(axis=1, how="any") → removes any columns (tickers) that have even a single missing value -> This step gives you a clean dataset — no NaNs
px = px.dropna(axis = 1, how="all")

px.head() #print first five rows
# Out:
# [*********************100%***********************]  16 of 16 completed
# Ticker       ADBE    ALB  BRK-B  GOOGL   MSFT  ONOF  PLTR   PYPL  QTUM  RNMBY  \
# Date
# 2020-11-01 478.47 128.19 228.91  87.12 205.26   NaN 27.11 214.12 37.47  16.73
# 2020-12-01 500.12 139.08 231.87  87.03 213.82   NaN 23.55 234.20 39.72  20.00
# 2021-01-01 458.77 153.77 227.87  90.74 222.99   NaN 35.18 234.31 42.54  19.48
# 2021-02-01 459.67 148.62 240.51 100.40 223.40 23.64 23.90 259.85 44.58  18.51
# 2021-03-01 475.37 138.13 255.47 102.42 227.18 24.53 23.29 242.84 45.03  18.49
#
# Ticker        RSP   TMUS    VOO  VXUS    VZ   XLE
# Date
# 2020-11-01 113.20 129.07 309.23 49.25 44.77 30.28
# 2020-12-01 117.49 130.92 319.51 51.62 43.54 31.22
# 2021-01-01 116.94 122.41 317.54 52.26 40.58 32.83
# 2021-02-01 124.06 116.48 326.32 53.47 41.42 40.20
# 2021-03-01 130.95 121.64 340.05 54.33 43.56 40.96

# %%
#calculate monthly returns
rets = px.pct_change().dropna() #command for calc returns

#print summary
print("\nMonthly returns computed.")
print("Shape:", rets.shape)
print("\nHead:")
print(rets.head(3))
print("\nSummary stats (monthly):")
print(rets.describe().T)
# Out:
# Monthly returns computed.
# Shape: (56, 16)
#
# Head:
# Ticker      ADBE   ALB  BRK-B  GOOGL  MSFT  ONOF  PLTR  PYPL  QTUM  RNMBY  \
# Date
# 2021-03-01  0.03 -0.07   0.06   0.02  0.02  0.04 -0.03 -0.07  0.01  -0.00
# 2021-04-01  0.07  0.15   0.08   0.14  0.07  0.05 -0.01  0.08  0.02   0.04
# 2021-05-01 -0.01 -0.01   0.05   0.00 -0.01  0.01 -0.00 -0.01 -0.00   0.01
#
# Ticker      RSP  TMUS  VOO  VXUS    VZ  XLE
# Date
# 2021-03-01 0.06  0.04 0.04  0.02  0.05 0.02
# 2021-04-01 0.05  0.05 0.06  0.03 -0.01 0.02
# 2021-05-01 0.02  0.07 0.01  0.03 -0.01 0.06
#
# Summary stats (monthly):
#         count  mean  std   min   25%   50%  75%  max
# Ticker
# ADBE    56.00  0.00 0.10 -0.26 -0.08 -0.01 0.07 0.25
# ALB     56.00  0.00 0.14 -0.25 -0.09 -0.02 0.13 0.35
# BRK-B   56.00  0.01 0.06 -0.14 -0.03  0.02 0.06 0.11
# GOOGL   56.00  0.02 0.08 -0.18 -0.04  0.03 0.08 0.15
# MSFT    56.00  0.02 0.07 -0.11 -0.04  0.02 0.07 0.18
# ONOF    56.00  0.01 0.04 -0.11 -0.02  0.02 0.04 0.09
# PLTR    56.00  0.06 0.22 -0.25 -0.08  0.04 0.15 0.90
# PYPL    56.00 -0.02 0.11 -0.35 -0.08 -0.00 0.07 0.24
# QTUM    56.00  0.02 0.07 -0.13 -0.01  0.02 0.06 0.15
# RNMBY   56.00  0.07 0.15 -0.21 -0.03  0.04 0.16 0.50
# RSP     56.00  0.01 0.05 -0.10 -0.03  0.01 0.04 0.10
# TMUS    56.00  0.01 0.06 -0.10 -0.02  0.01 0.06 0.16
# VOO     56.00  0.01 0.05 -0.10 -0.02  0.02 0.04 0.10
# VXUS    56.00  0.01 0.04 -0.10 -0.03  0.02 0.03 0.13
# VZ      56.00  0.00 0.06 -0.10 -0.04 -0.01 0.05 0.12
# XLE     56.00  0.02 0.08 -0.18 -0.01  0.02 0.04 0.26

# %%
#Annualized mean & covariance (pretty output, fixed)

# Compute annualized mean and covariance
mu = (1 + rets.mean()) ** 12 - 1   # pandas Series, annual compounded return
cov = rets.cov()  * 12             # pandas DataFrame, annual covar

# --- Ensure both are pandas objects with proper labels ---
mu_df = pd.DataFrame(mu, columns=["Annualized Mean"])   #create dataframe for annualized mean
mu_df["Annualized Mean (%)"] = mu_df["Annualized Mean"] * 100 #ceate dataframe for annualized mean in %

cov_df = pd.DataFrame(cov, index=rets.columns, columns=rets.columns) #creates df for covar

# --- Pretty display ---
print(" Annualized Statistics\n")

print("---- Annualized Mean Returns ----")
display(mu_df.style.format({
    "Annualized Mean": "{:.4f}",
    "Annualized Mean (%)": "{:.2f}%"
}))

print("\n---- Annualized Covariance Matrix ----")
display(cov_df.style.background_gradient(cmap="RdYlGn", axis=None).format("{:.4f}"))

# --- Add annualized volatility summary ---
ann_vol = np.sqrt(np.diag(cov_df))  #basically square root of the annual variance -> stdev = volatility
vol_df = pd.DataFrame({
    "Annualized Volatility": ann_vol,
    "Volatility (%)": ann_vol * 100
}, index=cov_df.columns)

print("\n---- Annualized Volatility ----")
display(vol_df.style.format({
    "Annualized Volatility": "{:.4f}",
    "Volatility (%)": "{:.2f}%"
}))

corr_df = rets.corr()
print("\n---- Correlation Matrix ----")
display(corr_df.style.background_gradient(cmap="coolwarm", axis=None).format("{:.3f}"))
# Out:
#  Annualized Statistics
#
# ---- Annualized Mean Returns ----
# <style type="text/css">
# </style>
# <table id="T_8c398">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c398_level0_col0" class="col_heading level0 col0" >Annualized Mean</th>
#       <th id="T_8c398_level0_col1" class="col_heading level0 col1" >Annualized Mean (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ticker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c398_level0_row0" class="row_heading level0 row0" >ADBE</th>
#       <td id="T_8c398_row0_col0" class="data row0 col0" >0.0068</td>
#       <td id="T_8c398_row0_col1" class="data row0 col1" >0.68%</td>
#     </tr>
#     <tr>
#       <th id="T_8c398_level0_row1" class="row_heading level0 row1" >ALB</th>
#       <td id="T_8c398_row1_col0" class="data row1 col0" >0.0273</td>
#       <td id="T_8c398_row1_col1" class="data row1 col1" >2.73%</td>
#     </tr>
#     <tr>
#       <th id="T_8c398_level0_row2" class="row_heading level0 row2" >BRK-B</th>
#       <td id="T_8c398_row2_col0" class="data row2 col0" >0.1855</td>
#       <td id="T_8c398_row2_col1" class="data row2 col1" >18.55%</td>
#     </tr>
#     <tr>
#       <th id="T_8c398_level0_row3" class="row_heading level0 row3" >GOOGL</th>
#       <td id="T_8c398_row3_col0" class="data row3 col0" >0.2656</td>
#       <td id="T_8c398_row3_col1" class="data row3 col1" >26.56%</td>
#     </tr>
#     <tr>
#       <th id="T_8c398_level0_row4" class="row_heading level0 row4" >MSFT</th>
#       <td id="T_8c398_row4_col0" class="data row4 col0" >0.2292</td>
#       <td id="T_8c398_row4_col1" class="data row4 col1" >22.92%</td>
#     </tr>
#     <tr>
#       <th id="T_8c398_level0_row5" class="row_heading level0 row5" >ONOF</th>
#       <td id="T_8c398_row5_col0" class="data row5 col0" >0.1146</td>
#       <td id="T_8c398_row5_col1" class="data row5 col1" >11.46%</td>
#     </tr>
#     <tr>
#       <th id="T_8c398_level0_row6" class="row_heading level0 row6" >PLTR</th>
#       <td id="T_8c398_row6_col0" class="data row6 col0" >0.9227</td>
#       <td id="T_8c398_row6_col1" class="data row6 col1" >92.27%</td>
#     </tr>
#     <tr>
#       <th id="T_8c398_level0_row7" class="row_heading level0 row7" >PYPL</th>
#       <td id="T_8c398_row7_col0" class="data row7 col0" >-0.1845</td>
#       <td id="T_8c398_row7_col1" class="data row7 col1" >-18.45%</td>
#     </tr>
#     <tr>
#       <th id="T_8c398_level0_row8" class="row_heading level0 row8" >QTUM</th>
#       <td id="T_8c398_row8_col0" class="data row8 col0" >0.2447</td>
#       <td id="T_8c398_row8_col1" class="data row8 col1" >24.47%</td>
#     </tr>
#     <tr>
#       <th id="T_8c398_level0_row9" class="row_heading level0 row9" >RNMBY</th>
#       <td id="T_8c398_row9_col0" class="data row9 col0" >1.1600</td>
#       <td id="T_8c398_row9_col1" class="data row9 col1" >116.00%</td>
#     </tr>
#     <tr>
#       <th id="T_8c398_level0_row10" class="row_heading level0 row10" >RSP</th>
#       <td id="T_8c398_row10_col0" class="data row10 col0" >0.1106</td>
#       <td id="T_8c398_row10_col1" class="data row10 col1" >11.06%</td>
#     </tr>
#     <tr>
#       <th id="T_8c398_level0_row11" class="row_heading level0 row11" >TMUS</th>
#       <td id="T_8c398_row11_col0" class="data row11 col0" >0.1684</td>
#       <td id="T_8c398_row11_col1" class="data row11 col1" >16.84%</td>
#     </tr>
#     <tr>
#       <th id="T_8c398_level0_row12" class="row_heading level0 row12" >VOO</th>
#       <td id="T_8c398_row12_col0" class="data row12 col0" >0.1603</td>
#       <td id="T_8c398_row12_col1" class="data row12 col1" >16.03%</td>
#     </tr>
#     <tr>
#       <th id="T_8c398_level0_row13" class="row_heading level0 row13" >VXUS</th>
#       <td id="T_8c398_row13_col0" class="data row13 col0" >0.0859</td>
#       <td id="T_8c398_row13_col1" class="data row13 col1" >8.59%</td>
#     </tr>
#     <tr>
#       <th id="T_8c398_level0_row14" class="row_heading level0 row14" >VZ</th>
#       <td id="T_8c398_row14_col0" class="data row14 col0" >0.0059</td>
#       <td id="T_8c398_row14_col1" class="data row14 col1" >0.59%</td>
#     </tr>
#     <tr>
#       <th id="T_8c398_level0_row15" class="row_heading level0 row15" >XLE</th>
#       <td id="T_8c398_row15_col0" class="data row15 col0" >0.2251</td>
#       <td id="T_8c398_row15_col1" class="data row15 col1" >22.51%</td>
#     </tr>
#   </tbody>
# </table>
# ---- Annualized Covariance Matrix ----
# <style type="text/css">
# #T_13866_row0_col0 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_13866_row0_col1, #T_13866_row0_col12, #T_13866_row1_col0, #T_13866_row1_col12, #T_13866_row2_col2, #T_13866_row3_col4, #T_13866_row4_col3, #T_13866_row7_col8, #T_13866_row7_col10, #T_13866_row8_col7, #T_13866_row10_col7, #T_13866_row12_col0, #T_13866_row12_col1 {
#   background-color: #e0422f;
#   color: #f1f1f1;
# }
# #T_13866_row0_col2, #T_13866_row0_col15, #T_13866_row2_col0, #T_13866_row5_col5, #T_13866_row5_col8, #T_13866_row8_col5, #T_13866_row8_col13, #T_13866_row10_col12, #T_13866_row12_col10, #T_13866_row13_col8, #T_13866_row13_col13, #T_13866_row15_col0 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_13866_row0_col3, #T_13866_row0_col7, #T_13866_row0_col8, #T_13866_row1_col10, #T_13866_row3_col0, #T_13866_row3_col8, #T_13866_row6_col12, #T_13866_row7_col0, #T_13866_row8_col0, #T_13866_row8_col3, #T_13866_row10_col1, #T_13866_row12_col6, #T_13866_row14_col14 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_13866_row0_col4, #T_13866_row4_col0, #T_13866_row4_col4 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_13866_row0_col5, #T_13866_row0_col13, #T_13866_row1_col13, #T_13866_row5_col0, #T_13866_row5_col6, #T_13866_row6_col5, #T_13866_row8_col12, #T_13866_row10_col10, #T_13866_row12_col8, #T_13866_row13_col0, #T_13866_row13_col1 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_13866_row0_col6, #T_13866_row3_col3, #T_13866_row6_col0 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_13866_row0_col9, #T_13866_row9_col0 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_13866_row0_col10, #T_13866_row5_col7, #T_13866_row6_col9, #T_13866_row7_col5, #T_13866_row9_col6, #T_13866_row10_col0 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_13866_row0_col11, #T_13866_row1_col4, #T_13866_row2_col14, #T_13866_row4_col1, #T_13866_row5_col13, #T_13866_row9_col15, #T_13866_row11_col0, #T_13866_row13_col5, #T_13866_row13_col15, #T_13866_row14_col2, #T_13866_row15_col9, #T_13866_row15_col13 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_13866_row0_col14, #T_13866_row2_col11, #T_13866_row2_col12, #T_13866_row3_col10, #T_13866_row4_col10, #T_13866_row4_col13, #T_13866_row5_col10, #T_13866_row6_col13, #T_13866_row10_col3, #T_13866_row10_col4, #T_13866_row10_col5, #T_13866_row11_col2, #T_13866_row11_col14, #T_13866_row11_col15, #T_13866_row12_col2, #T_13866_row12_col13, #T_13866_row13_col4, #T_13866_row13_col6, #T_13866_row13_col12, #T_13866_row14_col0, #T_13866_row14_col11, #T_13866_row15_col11 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_13866_row1_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_13866_row1_col2, #T_13866_row1_col11, #T_13866_row2_col1, #T_13866_row2_col7, #T_13866_row2_col10, #T_13866_row3_col5, #T_13866_row3_col13, #T_13866_row4_col5, #T_13866_row5_col3, #T_13866_row5_col4, #T_13866_row5_col12, #T_13866_row7_col2, #T_13866_row7_col15, #T_13866_row10_col2, #T_13866_row10_col13, #T_13866_row10_col15, #T_13866_row11_col1, #T_13866_row12_col5, #T_13866_row13_col3, #T_13866_row13_col10, #T_13866_row15_col7, #T_13866_row15_col10 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_13866_row1_col3, #T_13866_row1_col5, #T_13866_row3_col1, #T_13866_row3_col7, #T_13866_row5_col1, #T_13866_row7_col3 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_13866_row1_col6, #T_13866_row1_col15, #T_13866_row6_col1, #T_13866_row15_col1 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_13866_row1_col7, #T_13866_row7_col1 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_13866_row1_col8, #T_13866_row8_col1, #T_13866_row11_col11 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_13866_row1_col9, #T_13866_row9_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_13866_row1_col14, #T_13866_row3_col15, #T_13866_row4_col9, #T_13866_row4_col15, #T_13866_row7_col14, #T_13866_row9_col4, #T_13866_row14_col1, #T_13866_row14_col7, #T_13866_row15_col3, #T_13866_row15_col4 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_13866_row2_col3, #T_13866_row3_col2, #T_13866_row5_col11, #T_13866_row8_col9, #T_13866_row8_col15, #T_13866_row9_col8, #T_13866_row11_col5, #T_13866_row15_col8 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_13866_row2_col4, #T_13866_row4_col2, #T_13866_row4_col14, #T_13866_row9_col10, #T_13866_row10_col9, #T_13866_row11_col13, #T_13866_row12_col14, #T_13866_row13_col11, #T_13866_row14_col4, #T_13866_row14_col12, #T_13866_row14_col15, #T_13866_row15_col14 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_13866_row2_col5, #T_13866_row2_col8, #T_13866_row5_col2, #T_13866_row5_col15, #T_13866_row7_col11, #T_13866_row8_col2, #T_13866_row10_col14, #T_13866_row11_col7, #T_13866_row11_col12, #T_13866_row12_col11, #T_13866_row13_col14, #T_13866_row14_col10, #T_13866_row14_col13, #T_13866_row15_col5 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_13866_row2_col6, #T_13866_row2_col13, #T_13866_row6_col2, #T_13866_row9_col13, #T_13866_row10_col11, #T_13866_row11_col10, #T_13866_row12_col15, #T_13866_row13_col2, #T_13866_row13_col9, #T_13866_row15_col12 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_13866_row2_col9, #T_13866_row7_col13, #T_13866_row9_col2, #T_13866_row9_col11, #T_13866_row11_col9, #T_13866_row13_col7 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_13866_row2_col15, #T_13866_row3_col12, #T_13866_row4_col7, #T_13866_row4_col12, #T_13866_row6_col10, #T_13866_row7_col4, #T_13866_row8_col10, #T_13866_row10_col6, #T_13866_row10_col8, #T_13866_row12_col3, #T_13866_row12_col4, #T_13866_row12_col12, #T_13866_row15_col2 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_13866_row3_col6, #T_13866_row6_col3, #T_13866_row15_col15 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_13866_row3_col9, #T_13866_row9_col3 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_13866_row3_col11, #T_13866_row3_col14, #T_13866_row4_col11, #T_13866_row11_col3, #T_13866_row11_col4, #T_13866_row14_col3 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_13866_row4_col6, #T_13866_row6_col4 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_13866_row4_col8, #T_13866_row7_col12, #T_13866_row8_col4, #T_13866_row9_col14, #T_13866_row12_col7, #T_13866_row14_col9 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_13866_row5_col9, #T_13866_row9_col5 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_13866_row5_col14, #T_13866_row6_col11, #T_13866_row8_col11, #T_13866_row8_col14, #T_13866_row11_col6, #T_13866_row11_col8, #T_13866_row14_col5, #T_13866_row14_col8 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_13866_row6_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_13866_row6_col7, #T_13866_row7_col6 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_13866_row6_col8, #T_13866_row8_col6 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_13866_row6_col14, #T_13866_row14_col6 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_13866_row6_col15, #T_13866_row15_col6 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_13866_row7_col7 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_13866_row7_col9, #T_13866_row9_col7 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_13866_row8_col8 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_13866_row9_col9 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_13866_row9_col12, #T_13866_row12_col9 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_13866">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Ticker</th>
#       <th id="T_13866_level0_col0" class="col_heading level0 col0" >ADBE</th>
#       <th id="T_13866_level0_col1" class="col_heading level0 col1" >ALB</th>
#       <th id="T_13866_level0_col2" class="col_heading level0 col2" >BRK-B</th>
#       <th id="T_13866_level0_col3" class="col_heading level0 col3" >GOOGL</th>
#       <th id="T_13866_level0_col4" class="col_heading level0 col4" >MSFT</th>
#       <th id="T_13866_level0_col5" class="col_heading level0 col5" >ONOF</t
# ---- Annualized Volatility ----
# <style type="text/css">
# </style>
# <table id="T_12f73">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12f73_level0_col0" class="col_heading level0 col0" >Annualized Volatility</th>
#       <th id="T_12f73_level0_col1" class="col_heading level0 col1" >Volatility (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ticker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12f73_level0_row0" class="row_heading level0 row0" >ADBE</th>
#       <td id="T_12f73_row0_col0" class="data row0 col0" >0.3610</td>
#       <td id="T_12f73_row0_col1" class="data row0 col1" >36.10%</td>
#     </tr>
#     <tr>
#       <th id="T_12f73_level0_row1" class="row_heading level0 row1" >ALB</th>
#       <td id="T_12f73_row1_col0" class="data row1 col0" >0.4953</td>
#       <td id="T_12f73_row1_col1" class="data row1 col1" >49.53%</td>
#     </tr>
#     <tr>
#       <th id="T_12f73_level0_row2" class="row_heading level0 row2" >BRK-B</th>
#       <td id="T_12f73_row2_col0" class="data row2 col0" >0.1909</td>
#       <td id="T_12f73_row2_col1" class="data row2 col1" >19.09%</td>
#     </tr>
#     <tr>
#       <th id="T_12f73_level0_row3" class="row_heading level0 row3" >GOOGL</th>
#       <td id="T_12f73_row3_col0" class="data row3 col0" >0.2747</td>
#       <td id="T_12f73_row3_col1" class="data row3 col1" >27.47%</td>
#     </tr>
#     <tr>
#       <th id="T_12f73_level0_row4" class="row_heading level0 row4" >MSFT</th>
#       <td id="T_12f73_row4_col0" class="data row4 col0" >0.2277</td>
#       <td id="T_12f73_row4_col1" class="data row4 col1" >22.77%</td>
#     </tr>
#     <tr>
#       <th id="T_12f73_level0_row5" class="row_heading level0 row5" >ONOF</th>
#       <td id="T_12f73_row5_col0" class="data row5 col0" >0.1508</td>
#       <td id="T_12f73_row5_col1" class="data row5 col1" >15.08%</td>
#     </tr>
#     <tr>
#       <th id="T_12f73_level0_row6" class="row_heading level0 row6" >PLTR</th>
#       <td id="T_12f73_row6_col0" class="data row6 col0" >0.7468</td>
#       <td id="T_12f73_row6_col1" class="data row6 col1" >74.68%</td>
#     </tr>
#     <tr>
#       <th id="T_12f73_level0_row7" class="row_heading level0 row7" >PYPL</th>
#       <td id="T_12f73_row7_col0" class="data row7 col0" >0.3821</td>
#       <td id="T_12f73_row7_col1" class="data row7 col1" >38.21%</td>
#     </tr>
#     <tr>
#       <th id="T_12f73_level0_row8" class="row_heading level0 row8" >QTUM</th>
#       <td id="T_12f73_row8_col0" class="data row8 col0" >0.2335</td>
#       <td id="T_12f73_row8_col1" class="data row8 col1" >23.35%</td>
#     </tr>
#     <tr>
#       <th id="T_12f73_level0_row9" class="row_heading level0 row9" >RNMBY</th>
#       <td id="T_12f73_row9_col0" class="data row9 col0" >0.5081</td>
#       <td id="T_12f73_row9_col1" class="data row9 col1" >50.81%</td>
#     </tr>
#     <tr>
#       <th id="T_12f73_level0_row10" class="row_heading level0 row10" >RSP</th>
#       <td id="T_12f73_row10_col0" class="data row10 col0" >0.1637</td>
#       <td id="T_12f73_row10_col1" class="data row10 col1" >16.37%</td>
#     </tr>
#     <tr>
#       <th id="T_12f73_level0_row11" class="row_heading level0 row11" >TMUS</th>
#       <td id="T_12f73_row11_col0" class="data row11 col0" >0.2089</td>
#       <td id="T_12f73_row11_col1" class="data row11 col1" >20.89%</td>
#     </tr>
#     <tr>
#       <th id="T_12f73_level0_row12" class="row_heading level0 row12" >VOO</th>
#       <td id="T_12f73_row12_col0" class="data row12 col0" >0.1579</td>
#       <td id="T_12f73_row12_col1" class="data row12 col1" >15.79%</td>
#     </tr>
#     <tr>
#       <th id="T_12f73_level0_row13" class="row_heading level0 row13" >VXUS</th>
#       <td id="T_12f73_row13_col0" class="data row13 col0" >0.1502</td>
#       <td id="T_12f73_row13_col1" class="data row13 col1" >15.02%</td>
#     </tr>
#     <tr>
#       <th id="T_12f73_level0_row14" class="row_heading level0 row14" >VZ</th>
#       <td id="T_12f73_row14_col0" class="data row14 col0" >0.2040</td>
#       <td id="T_12f73_row14_col1" class="data row14 col1" >20.40%</td>
#     </tr>
#     <tr>
#       <th id="T_12f73_level0_row15" class="row_heading level0 row15" >XLE</th>
#       <td id="T_12f73_row15_col0" class="data row15 col0" >0.2605</td>
#       <td id="T_12f73_row15_col1" class="data row15 col1" >26.05%</td>
#     </tr>
#   </tbody>
# </table>
# ---- Correlation Matrix ----
# <style type="text/css">
# #T_88325_row0_col0, #T_88325_row1_col1, #T_88325_row2_col2, #T_88325_row3_col3, #T_88325_row4_col4, #T_88325_row5_col5, #T_88325_row6_col6, #T_88325_row7_col7, #T_88325_row8_col8, #T_88325_row9_col9, #T_88325_row10_col10, #T_88325_row11_col11, #T_88325_row12_col12, #T_88325_row13_col13, #T_88325_row14_col14, #T_88325_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_88325_row0_col1, #T_88325_row1_col0, #T_88325_row7_col15, #T_88325_row15_col7 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_88325_row0_col2, #T_88325_row2_col0 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_88325_row0_col3, #T_88325_row3_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_88325_row0_col4, #T_88325_row4_col0, #T_88325_row5_col13, #T_88325_row13_col5 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_88325_row0_col5, #T_88325_row5_col0, #T_88325_row10_col15, #T_88325_row15_col10 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_88325_row0_col6, #T_88325_row2_col8, #T_88325_row5_col15, #T_88325_row6_col0, #T_88325_row8_col2, #T_88325_row15_col5 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_88325_row0_col7, #T_88325_row7_col0 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_88325_row0_col8, #T_88325_row8_col0 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_88325_row0_col9, #T_88325_row9_col0 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_88325_row0_col10, #T_88325_row10_col0 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_88325_row0_col11, #T_88325_row11_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_88325_row0_col12, #T_88325_row12_col0 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_88325_row0_col13, #T_88325_row4_col10, #T_88325_row10_col4, #T_88325_row13_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_88325_row0_col14, #T_88325_row14_col0 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_88325_row0_col15, #T_88325_row15_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_88325_row1_col2, #T_88325_row2_col1, #T_88325_row9_col13, #T_88325_row13_col9 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_88325_row1_col3, #T_88325_row3_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_88325_row1_col4, #T_88325_row4_col1 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_88325_row1_col5, #T_88325_row5_col1 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_88325_row1_col6, #T_88325_row6_col1, #T_88325_row8_col15, #T_88325_row15_col8 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_88325_row1_col7, #T_88325_row7_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_88325_row1_col8, #T_88325_row8_col1 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_88325_row1_col9, #T_88325_row5_col9, #T_88325_row9_col1, #T_88325_row9_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_88325_row1_col10, #T_88325_row2_col15, #T_88325_row10_col1, #T_88325_row15_col2 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_88325_row1_col11, #T_88325_row5_col11, #T_88325_row11_col1, #T_88325_row11_col5 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_88325_row1_col12, #T_88325_row10_col11, #T_88325_row11_col10, #T_88325_row12_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_88325_row1_col13, #T_88325_row12_col15, #T_88325_row13_col1, #T_88325_row15_col12 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_88325_row1_col14, #T_88325_row14_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_88325_row1_col15, #T_88325_row11_col15, #T_88325_row15_col1, #T_88325_row15_col11 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_88325_row2_col3, #T_88325_row2_col6, #T_88325_row3_col2, #T_88325_row6_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_88325_row2_col4, #T_88325_row4_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_88325_row2_col5, #T_88325_row5_col2 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_88325_row2_col7, #T_88325_row7_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_88325_row2_col9, #T_88325_row9_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_88325_row2_col10, #T_88325_row10_col2 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_88325_row2_col11, #T_88325_row11_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_88325_row2_col12, #T_88325_row2_col13, #T_88325_row3_col4, #T_88325_row4_col3, #T_88325_row12_col2, #T_88325_row13_col2 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_88325_row2_col14, #T_88325_row3_col7, #T_88325_row7_col3, #T_88325_row14_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_88325_row3_col5, #T_88325_row5_col3 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_88325_row3_col6, #T_88325_row6_col3, #T_88325_row9_col14, #T_88325_row14_col9 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_88325_row3_col8, #T_88325_row8_col3, #T_88325_row8_col10, #T_88325_row10_col8 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_88325_row3_col9, #T_88325_row9_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_88325_row3_col10, #T_88325_row7_col8, #T_88325_row8_col7, #T_88325_row10_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_88325_row3_col11, #T_88325_row11_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_88325_row3_col12, #T_88325_row12_col3 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_88325_row3_col13, #T_88325_row6_col8, #T_88325_row8_col6, #T_88325_row13_col3 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_88325_row3_col14, #T_88325_row14_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_88325_row3_col15, #T_88325_row15_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_88325_row4_col5, #T_88325_row5_col4 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_88325_row4_col6, #T_88325_row6_col4 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_88325_row4_col7, #T_88325_row7_col4, #T_88325_row9_col11, #T_88325_row11_col9 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_88325_row4_col8, #T_88325_row8_col4 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_88325_row4_col9, #T_88325_row9_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_88325_row4_col11, #T_88325_row11_col4 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_88325_row4_col12, #T_88325_row12_col4 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_88325_row4_col13, #T_88325_row13_col4 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_88325_row4_col14, #T_88325_row14_col4 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_88325_row4_col15, #T_88325_row15_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_88325_row5_col6, #T_88325_row6_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_88325_row5_col7, #T_88325_row7_col5 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_88325_row5_col8, #T_88325_row8_col5 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_88325_row5_col10, #T_88325_row10_col5 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_88325_row5_col12, #T_88325_row12_col5 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_88325_row5_col14, #T_88325_row9_col15, #T_88325_row14_col5, #T_88325_row15_col9 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_88325_row6_col7, #T_88325_row7_col6 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_88325_row6_col9, #T_88325_row9_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_88325_row6_col10, #T_88325_row10_col6 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_88325_row6_col11, #T_88325_row11_col6 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_88325_row6_col12, #T_88325_row12_col6 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_88325_row6_col13, #T_88325_row13_col6, #T_88325_row14_col15, #T_88325_row15_col14 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_88325_row6_col14, #T_88325_row14_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_88325_row6_col15, #T_88325_row15_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1

# %% [markdown]
# **Covariance** -> measures how two variables move together — in direction and magnitude, but not standardized
#
# - CoVar **<0** Stock A and B tend to move in **opposite** directions
#
# - CoVar **>0** Stock A and B tend to move in the **same** direction
#
# - CoVar **around 0** no relationship
#
#
# _Example:_
# If AAPL and MSFT both go up and down together, their covariance is positive.
# If AAPL rises when Gold falls, their covariance is negative.
#
# _Covariance_ is used in the covariance matrix (Σ) to calculate _portfolio variance_

# %% [markdown]
# **Correlation**
# -> standardized version of covariance — it measures the strength and direction of the relationship, independent of scale.
#
# - Corr: **+1** Perfect **positive** relationship (move exactly together)
#
# - Corr: **-1** Perfect **negative** relationship (move exactly opposite)
#
# - Corr: **0** no linear relationship
#
# **Correlation** is mainly used to understand diversification potential:
#
# - _Negative correlation_ → high diversification benefit.
# - _High correlation_ → assets behave similarly, limited diversification.

# %%
#Monte Carlo portfolios (long-only, weights >= 0, sum to 1)

#Monte Carlo Simulation is used in stats for simulating different events for different outcomes, very interesting concept :)

N = 3000 #number of portfolio simulations
n_assets = len(rets.columns) #number of investable asssets (= to number of columns in the return table, here 3 etfs)

weights = np.random.dirichlet(np.ones(n_assets), size=N) # Random weights that each sum to 1

mu_vec  = mu_df["Annualized Mean"].values #Pulls  annualized expected returns vector (shape (n_assets,)).
cov_mat = cov_df.values                   #Pulls  annualized covar matrix (shape (n_assets, n_assets)), .values ensures NumPy arrays for fast linear algebra.



#Matrix–vector multiply: (N, n_assets) @ (n_assets,) → (N,)
port_rets = weights @ mu_vec #For each portfolio row w, computes expected return μ_p = wᵀ μ

#Efficiently computes all portfolio variances σ_p² = wᵀ Σ w in one go
#Shapes: weights (N×A), cov_mat (A×A), weights (N×A)
#Multiply weights and cov_mat, then elementwise with weights, and sum over asset axes
#The -> i means “give me the N diagonal results only” (one per portfolio).
port_vars = np.einsum("ij,jk,ik->i", weights, cov_mat, weights)

#square root of port_vars = port_stdev
port_stds = np.sqrt(port_vars)

print("Portfolio simulation")
print("\nWeights row sums (first 5):", np.round(weights[:5].sum(axis=1), 6))
print("\nFirst 5 portfolios (σ, μ):")
for s, r in list(zip(port_stds[:5], port_rets[:5])):
    print(f"  sigma={s:.2%}, mu={r:.2%}")
# Out:
# Portfolio simulation
#
# Weights row sums (first 5): [1. 1. 1. 1. 1.]
#
# First 5 portfolios (σ, μ):
#   sigma=16.77%, mu=34.05%
#   sigma=17.86%, mu=20.27%
#   sigma=16.07%, mu=18.10%
#   sigma=16.33%, mu=12.75%
#   sigma=17.18%, mu=19.64%

# %%
#simple plotting to check if we are on the right track

from matplotlib.ticker import PercentFormatter #import the percentformatter from the plot package

START = str(px.index.min().date())
END = str(px.index.max().date())

plt.figure(figsize=(8,5))
plt.scatter(port_stds, port_rets, s=18, alpha=0.7)
plt.title(f"{n_assets}-Asset Portfolio Cloud (Monthly Adj, {START[:4]}–{END[:4]})")
plt.xlabel("Portfolio Std Dev")
plt.ylabel("Portfolio Return")
plt.gca().xaxis.set_major_formatter(PercentFormatter(1.0))
plt.gca().yaxis.set_major_formatter(PercentFormatter(1.0))
plt.grid(True, alpha=0.3)
plt.show()

print("Plot shown.")
# Out:
# Plot shown.

# %%
#Extremes: Max-Sharpe and Min-Variance (completely clean print)
rf = 0.04  #4% risk-free rate, 4% is reasonable for today's times

# Why Sharpe? -> Sharpe ratio measures how much excess return (above the risk-free rate) investor earns per unit of risk taken
# -> tells us how efficiently a portfolio converts risk into return
#The higher the Sharpe ratio, the better the risk-adjusted performance

sharpe = (port_rets - rf) / port_stds #normal sharpe formula
ix_s   = int(np.argmax(sharpe))      # max Sharpe, find portfolio with highest sharpe ratio
ix_m   = int(np.argmin(port_stds))   # min variance, find the minimum-variance portfolio

def clean_weights(w):
    """Return a dict with plain floats rounded to 3 decimals."""
    return {str(col): round(float(w[i]), 3) for i, col in enumerate(rets.columns)} #cleaning up for better visualization (not needed)

print(f"\nMax-Sharpe portfolio (rf={rf:.2%})")
print(f"  σ={float(port_stds[ix_s]):.2%}  μ={float(port_rets[ix_s]):.2%}  Sharpe={float(sharpe[ix_s]):.3f}")
print("  weights:", clean_weights(weights[ix_s]))

print("\nMin-Variance portfolio")
print(f"  σ={float(port_stds[ix_m]):.2%}  μ={float(port_rets[ix_m]):.2%}")
print("  weights:", clean_weights(weights[ix_m]))
# Out:
# Max-Sharpe portfolio (rf=4.00%)
#   σ=20.01%  μ=52.02%  Sharpe=2.400
#   weights: {'ADBE': 0.001, 'ALB': 0.012, 'BRK-B': 0.022, 'GOOGL': 0.043, 'MSFT': 0.06, 'ONOF': 0.191, 'PLTR': 0.083, 'PYPL': 0.013, 'QTUM': 0.048, 'RNMBY': 0.303, 'RSP': 0.007, 'TMUS': 0.015, 'VOO': 0.079, 'VXUS': 0.024, 'VZ': 0.041, 'XLE': 0.058}
#
# Min-Variance portfolio
#   σ=13.41%  μ=10.97%
#   weights: {'ADBE': 0.005, 'ALB': 0.041, 'BRK-B': 0.047, 'GOOGL': 0.073, 'MSFT': 0.038, 'ONOF': 0.16, 'PLTR': 0.008, 'PYPL': 0.017, 'QTUM': 0.017, 'RNMBY': 0.004, 'RSP': 0.084, 'TMUS': 0.027, 'VOO': 0.032, 'VXUS': 0.01, 'VZ': 0.354, 'XLE': 0.084}

# %%
#simple plotting

plt.figure(figsize=(8,5))
plt.scatter(port_stds, port_rets, s=12, alpha=0.5, label="Random Portfolios")
plt.scatter([port_stds[ix_s]], [port_rets[ix_s]], s=90, marker="*", label="Max Sharpe")
plt.scatter([port_stds[ix_m]], [port_rets[ix_m]], s=90, marker="D", label="Min Variance")
plt.title("Portfolio Cloud with Key Portfolios")
plt.xlabel("Portfolio Std Dev"); plt.ylabel("Portfolio Return")
plt.gca().xaxis.set_major_formatter(PercentFormatter(1.0))
plt.gca().yaxis.set_major_formatter(PercentFormatter(1.0))
plt.grid(True, alpha=0.3); plt.legend()
plt.show()
